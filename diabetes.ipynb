# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
table1 = pd.read_csv("diabetes.csv")

# %%
table1
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
table1.shape
# Out:
# (768, 9)

# %%
table1['Pregnancies'].isnull().sum()
# Out:
# 0

# %%
table1['BloodPressure'].isnull().sum()
# Out:
# 0

# %%
table1['Glucose'].isnull().sum()
# Out:
# 0

# %%
table1['SkinThickness'].isnull().sum()
# Out:
# 0

# %%
table1['Insulin'].isnull().sum()
# Out:
# 0

# %%
table1['BMI'].isnull().sum()
# Out:
# 0

# %%
table1['DiabetesPedigreeFunction'].isnull().sum()
# Out:
# 0

# %%
table1['Age'].isnull().sum()
# Out:
# 0

# %%
table1['Outcome'].isnull().sum()
# Out:
# 0

# %%
features = ['Glucose', 'BloodPressure', 'SkinThickness', 'BMI', 'DiabetesPedigreeFunction']

# %%
labels = ['Outcome']

# %%
x = table1[features].values

# %%
y = table1[labels].values

# %%
model = LinearRegression()

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.5
                                                   )

# %%
clf = model.fit(x, y)

# %%
pred = model.predict(x)

# %%
pred
# Out:
# array([[ 5.38009388e-01],
#        [ 3.19749713e-02],
#        [ 6.78855680e-01],
#        [ 5.86921418e-02],
#        [ 8.68534740e-01],
#        [ 2.15111806e-01],
#        [ 5.08782413e-02],
#        [ 4.29526481e-01],
#        [ 7.26609501e-01],
#        [-9.42475711e-02],
#        [ 3.10952391e-01],
#        [ 7.48372704e-01],
#        [ 5.40435374e-01],
#        [ 7.45568419e-01],
#        [ 5.60465290e-01],
#        [ 3.14485751e-01],
#        [ 4.71954322e-01],
#        [ 2.19616691e-01],
#        [ 3.80017525e-01],
#        [ 3.41950722e-01],
#        [ 4.58430012e-01],
#        [ 2.51668703e-01],
#        [ 9.12162290e-01],
#        [ 2.36004832e-01],
#        [ 4.67685748e-01],
#        [ 3.17837487e-01],
#        [ 5.95321987e-01],
#        [ 9.73432284e-02],
#        [ 3.21637188e-01],
#        [ 3.28109295e-01],
#        [ 3.23720797e-01],
#        [ 5.97708218e-01],
#        [ 4.82671534e-02],
#        [-3.57459809e-02],
#        [ 2.78055330e-01],
# ...

# %%
pred.mean()
# Out:
# 0.34895833333333326

# %%
import matplotlib.pyplot as lib

# %%
lib.plot(y, pred)

# %%
lib.plot(x, pred)

# %%
from sklearn.metrics import r2_score #if r2_score is closer to 1 we can say that the model is better

# %%
print(r2_score(y, pred))
# Out:
# 0.26810904843150973
