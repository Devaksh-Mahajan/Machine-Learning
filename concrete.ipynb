# %%
import pandas as pd
import numpy as np

# %%
cement = pd.read_csv('concrete.csv')

# %%
table1 = pd.DataFrame(cement)

# %%
table1
# Out:
#       cement   slag    ash  water  superplastic  coarseagg  fineagg  age  \
# 0      141.3  212.0    0.0  203.5           0.0      971.8    748.5   28
# 1      168.9   42.2  124.3  158.3          10.8     1080.8    796.2   14
# 2      250.0    0.0   95.7  187.4           5.5      956.9    861.2   28
# 3      266.0  114.0    0.0  228.0           0.0      932.0    670.0   28
# 4      154.8  183.4    0.0  193.3           9.1     1047.4    696.7   28
# ...      ...    ...    ...    ...           ...        ...      ...  ...
# 1025   135.0    0.0  166.0  180.0          10.0      961.0    805.0   28
# 1026   531.3    0.0    0.0  141.8          28.2      852.1    893.7    3
# 1027   276.4  116.0   90.3  179.6           8.9      870.1    768.3   28
# 1028   342.0   38.0    0.0  228.0           0.0      932.0    670.0  270
# 1029   540.0    0.0    0.0  173.0           0.0     1125.0    613.0    7
#
#       strength
# 0        29.89
# 1        23.51
# 2        29.22
# 3        45.85
# ...

# %%
table1.head()
# Out:
#    cement   slag    ash  water  superplastic  coarseagg  fineagg  age  \
# 0   141.3  212.0    0.0  203.5           0.0      971.8    748.5   28
# 1   168.9   42.2  124.3  158.3          10.8     1080.8    796.2   14
# 2   250.0    0.0   95.7  187.4           5.5      956.9    861.2   28
# 3   266.0  114.0    0.0  228.0           0.0      932.0    670.0   28
# 4   154.8  183.4    0.0  193.3           9.1     1047.4    696.7   28
#
#    strength
# 0     29.89
# 1     23.51
# 2     29.22
# 3     45.85
# 4     18.29

# %%
table1 = table1.dropna()
table1
# Out:
#       cement   slag    ash  water  superplastic  coarseagg  fineagg  age  \
# 0      141.3  212.0    0.0  203.5           0.0      971.8    748.5   28
# 1      168.9   42.2  124.3  158.3          10.8     1080.8    796.2   14
# 2      250.0    0.0   95.7  187.4           5.5      956.9    861.2   28
# 3      266.0  114.0    0.0  228.0           0.0      932.0    670.0   28
# 4      154.8  183.4    0.0  193.3           9.1     1047.4    696.7   28
# ...      ...    ...    ...    ...           ...        ...      ...  ...
# 1025   135.0    0.0  166.0  180.0          10.0      961.0    805.0   28
# 1026   531.3    0.0    0.0  141.8          28.2      852.1    893.7    3
# 1027   276.4  116.0   90.3  179.6           8.9      870.1    768.3   28
# 1028   342.0   38.0    0.0  228.0           0.0      932.0    670.0  270
# 1029   540.0    0.0    0.0  173.0           0.0     1125.0    613.0    7
#
#       strength
# 0        29.89
# 1        23.51
# 2        29.22
# 3        45.85
# ...

# %%
table = pd.DataFrame()
table['cement'] = table1['cement']
table['water'] = table1['water']
table
# Out:
#       cement  water
# 0      141.3  203.5
# 1      168.9  158.3
# 2      250.0  187.4
# 3      266.0  228.0
# 4      154.8  193.3
# ...      ...    ...
# 1025   135.0  180.0
# 1026   531.3  141.8
# 1027   276.4  179.6
# 1028   342.0  228.0
# 1029   540.0  173.0
#
# [1030 rows x 2 columns]

# %%
mean_of_cement = table['cement'].mean()
mean_of_water = table['water'].mean()
print(mean_of_cement)
print(mean_of_water)
# Out:
# 281.1678640776698
# 181.56728155339798

# %%
table['cement-mean_of_cement'] = table['cement']-mean_of_cement

# %%
print(table)
# Out:
#       cement  water  cement-mean_of_cement
# 0      141.3  203.5            -139.867864
# 1      168.9  158.3            -112.267864
# 2      250.0  187.4             -31.167864
# 3      266.0  228.0             -15.167864
# 4      154.8  193.3            -126.367864
# ...      ...    ...                    ...
# 1025   135.0  180.0            -146.167864
# 1026   531.3  141.8             250.132136
# 1027   276.4  179.6              -4.767864
# 1028   342.0  228.0              60.832136
# 1029   540.0  173.0             258.832136
#
# [1030 rows x 3 columns]

# %%
table['water-mean_of_water'] = table['water'] - mean_of_water

# %%
print(table)
# Out:
#       cement  water  cement-mean_of_cement  water-mean_of_water
# 0      141.3  203.5            -139.867864            21.932718
# 1      168.9  158.3            -112.267864           -23.267282
# 2      250.0  187.4             -31.167864             5.832718
# 3      266.0  228.0             -15.167864            46.432718
# 4      154.8  193.3            -126.367864            11.732718
# ...      ...    ...                    ...                  ...
# 1025   135.0  180.0            -146.167864            -1.567282
# 1026   531.3  141.8             250.132136           -39.767282
# 1027   276.4  179.6              -4.767864            -1.967282
# 1028   342.0  228.0              60.832136            46.432718
# 1029   540.0  173.0             258.832136            -8.567282
#
# [1030 rows x 4 columns]

# %%
table
# Out:
#       cement  water  cement-mean_of_cement  water-mean_of_water  \
# 0      141.3  203.5            -139.867864            21.932718
# 1      168.9  158.3            -112.267864           -23.267282
# 2      250.0  187.4             -31.167864             5.832718
# 3      266.0  228.0             -15.167864            46.432718
# 4      154.8  193.3            -126.367864            11.732718
# ...      ...    ...                    ...                  ...
# 1025   135.0  180.0            -146.167864            -1.567282
# 1026   531.3  141.8             250.132136           -39.767282
# 1027   276.4  179.6              -4.767864            -1.967282
# 1028   342.0  228.0              60.832136            46.432718
# 1029   540.0  173.0             258.832136            -8.567282
#
#       product of cement-mean_of_cement and water-mean_of_water
# 0                                          -3067.682483
# 1                                           2612.168003
# ...

# %%
del table['product of cement-mean_of_cement and water-mean_of_water']

# %%
table
# Out:
#       cement  water  cement-mean_of_cement  water-mean_of_water
# 0      141.3  203.5            -139.867864            21.932718
# 1      168.9  158.3            -112.267864           -23.267282
# 2      250.0  187.4             -31.167864             5.832718
# 3      266.0  228.0             -15.167864            46.432718
# 4      154.8  193.3            -126.367864            11.732718
# ...      ...    ...                    ...                  ...
# 1025   135.0  180.0            -146.167864            -1.567282
# 1026   531.3  141.8             250.132136           -39.767282
# 1027   276.4  179.6              -4.767864            -1.967282
# 1028   342.0  228.0              60.832136            46.432718
# 1029   540.0  173.0             258.832136            -8.567282
#
# [1030 rows x 4 columns]

# %%
table['product of cement-mean_of_cement and water-mean_of_water'] = table['cement-mean_of_cement'] * table['water-mean_of_water']

# %%
table
# Out:
#       cement  water  cement-mean_of_cement  water-mean_of_water  \
# 0      141.3  203.5            -139.867864            21.932718
# 1      168.9  158.3            -112.267864           -23.267282
# 2      250.0  187.4             -31.167864             5.832718
# 3      266.0  228.0             -15.167864            46.432718
# 4      154.8  193.3            -126.367864            11.732718
# ...      ...    ...                    ...                  ...
# 1025   135.0  180.0            -146.167864            -1.567282
# 1026   531.3  141.8             250.132136           -39.767282
# 1027   276.4  179.6              -4.767864            -1.967282
# 1028   342.0  228.0              60.832136            46.432718
# 1029   540.0  173.0             258.832136            -8.567282
#
#       product of cement-mean_of_cement and water-mean_of_water
# 0                                          -3067.682483
# 1                                           2612.168003
# ...

# %%
sumo = table['product of cement-mean_of_cement and water-mean_of_water'].sum()
print(sumo)
# Out:
# -187353.3329805825

# %%
sumo1 = table['cement-mean_of_cement'].sum()
print(sumo1)
# Out:
# 1.318767317570746e-10

# %%
m = sumo/sumo1
print(m)
# Out:
# -1420670124929235.8

# %%
y_intercept = mean_of_water - m*mean_of_cement

# %%
print(y_intercept)
# Out:
# 3.994467845853097e+17

# %%
table['y_predicted'] = m*table['cement'] + y_intercept

# %%
table
# Out:
#       cement  water  cement-mean_of_cement  water-mean_of_water  \
# 0      141.3  203.5            -139.867864            21.932718
# 1      168.9  158.3            -112.267864           -23.267282
# 2      250.0  187.4             -31.167864             5.832718
# 3      266.0  228.0             -15.167864            46.432718
# 4      154.8  193.3            -126.367864            11.732718
# ...      ...    ...                    ...                  ...
# 1025   135.0  180.0            -146.167864            -1.567282
# 1026   531.3  141.8             250.132136           -39.767282
# 1027   276.4  179.6              -4.767864            -1.967282
# 1028   342.0  228.0              60.832136            46.432718
# 1029   540.0  173.0             258.832136            -8.567282
#
#       product of cement-mean_of_cement and water-mean_of_water   y_predicted
# 0                                          -3067.682483         1.987061e+17
# ...

# %%
table['water - mean_of_water'] = table['water'] - mean_of_water

# %%
table['square of water-mean_of_water'] = table['water - mean_of_water'] * table['water - mean_of_water']

# %%
table
# Out:
#       cement  water  cement-mean_of_cement  water-mean_of_water  \
# 0      141.3  203.5            -139.867864            21.932718
# 1      168.9  158.3            -112.267864           -23.267282
# 2      250.0  187.4             -31.167864             5.832718
# 3      266.0  228.0             -15.167864            46.432718
# 4      154.8  193.3            -126.367864            11.732718
# ...      ...    ...                    ...                  ...
# 1025   135.0  180.0            -146.167864            -1.567282
# 1026   531.3  141.8             250.132136           -39.767282
# 1027   276.4  179.6              -4.767864            -1.967282
# 1028   342.0  228.0              60.832136            46.432718
# 1029   540.0  173.0             258.832136            -8.567282
#
#       product of cement-mean_of_cement and water-mean_of_water   y_predicted  \
# 0                                          -3067.682483         1.987061e+17
# ...

# %%
table['y_predicted - mean_of_water'] = table['y_predicted']-mean_of_water

# %%
table
# Out:
#       cement  water  cement-mean_of_cement  water-mean_of_water  \
# 0      141.3  203.5            -139.867864            21.932718
# 1      168.9  158.3            -112.267864           -23.267282
# 2      250.0  187.4             -31.167864             5.832718
# 3      266.0  228.0             -15.167864            46.432718
# 4      154.8  193.3            -126.367864            11.732718
# ...      ...    ...                    ...                  ...
# 1025   135.0  180.0            -146.167864            -1.567282
# 1026   531.3  141.8             250.132136           -39.767282
# 1027   276.4  179.6              -4.767864            -1.967282
# 1028   342.0  228.0              60.832136            46.432718
# 1029   540.0  173.0             258.832136            -8.567282
#
#       product of cement-mean_of_cement and water-mean_of_water   y_predicted  \
# 0                                          -3067.682483         1.987061e+17
# ...

# %%
table['square of y_predicted - mean_of_water'] = table['y_predicted - mean_of_water'] * table['y_predicted - mean_of_water']

# %%
table
# Out:
#       cement  water  cement-mean_of_cement  water-mean_of_water  \
# 0      141.3  203.5            -139.867864            21.932718
# 1      168.9  158.3            -112.267864           -23.267282
# 2      250.0  187.4             -31.167864             5.832718
# 3      266.0  228.0             -15.167864            46.432718
# 4      154.8  193.3            -126.367864            11.732718
# ...      ...    ...                    ...                  ...
# 1025   135.0  180.0            -146.167864            -1.567282
# 1026   531.3  141.8             250.132136           -39.767282
# 1027   276.4  179.6              -4.767864            -1.967282
# 1028   342.0  228.0              60.832136            46.432718
# 1029   540.0  173.0             258.832136            -8.567282
#
#       product of cement-mean_of_cement and water-mean_of_water   y_predicted  \
# 0                                          -3067.682483         1.987061e+17
# ...

# %%
sum1 = table['square of y_predicted - mean_of_water'].sum()
print(sum1)
# Out:
# 2.268231359460337e+37

# %%
table['square of water-mean_of_water'] = table['water - mean_of_water'] * table['water - mean_of_water']
table
# Out:
#       cement  water  cement-mean_of_cement  water-mean_of_water  \
# 0      141.3  203.5            -139.867864            21.932718
# 1      168.9  158.3            -112.267864           -23.267282
# 2      250.0  187.4             -31.167864             5.832718
# 3      266.0  228.0             -15.167864            46.432718
# 4      154.8  193.3            -126.367864            11.732718
# ...      ...    ...                    ...                  ...
# 1025   135.0  180.0            -146.167864            -1.567282
# 1026   531.3  141.8             250.132136           -39.767282
# 1027   276.4  179.6              -4.767864            -1.967282
# 1028   342.0  228.0              60.832136            46.432718
# 1029   540.0  173.0             258.832136            -8.567282
#
#       product of cement-mean_of_cement and water-mean_of_water   y_predicted  \
# 0                                          -3067.682483         1.987061e+17
# ...

# %%
sum1 = table['square of y_predicted - mean_of_water'].sum()

# %%
sum2 = table['square of water-mean_of_water'].sum()

# %%
r_square = sum1/sum2
print(r_square)
# Out:
# 4.833977322828553e+31

# %%
import matplotlib.pyplot as lib

# %%
ax = lib.gca()
table1.plot(kind = 'scatter',x = 'cement', color = 'red', y = 'water',ax = ax )
# Out:
# <AxesSubplot:xlabel='cement', ylabel='water'>

# %%
lib.plot(mean_of_cement, mean_of_water, marker = 'o')

# %%
lib.scatter(table['cement'], table['water'])
lib.plot(table['cement'], table['y_predicted'], color='red')
lib.show()

# %%
lib.scatter(table['cement'], table['y_predicted'], color = 'black')
